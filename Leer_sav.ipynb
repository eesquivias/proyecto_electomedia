# %% [markdown]
# ### Archivos .sav (SPSS) con Pandas

# %%
import pandas as pd
import pyreadstat

df, meta = pyreadstat.read_sav('./CIS/MD3263_macrobarometro_19/3263.sav')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#          ESTU     CUES  CCAA  PROV   MUN  TAMUNI  CAPITAL  DISTR  SECCION  \
# 0      3263.0      1.0  16.0   1.0  59.0     5.0      1.0    0.0      0.0
# 1      3263.0      2.0  16.0   1.0  59.0     5.0      1.0    0.0      0.0
# 2      3263.0      3.0  16.0   1.0  59.0     5.0      1.0    0.0      0.0
# 3      3263.0      4.0  16.0   1.0  59.0     5.0      1.0    0.0      0.0
# 4      3263.0      5.0  16.0   1.0  59.0     5.0      1.0    0.0      0.0
# ...       ...      ...   ...   ...   ...     ...      ...    ...      ...
# 17645  3263.0  18005.0  13.0  28.0  79.0     7.0      1.0    0.0      0.0
# 17646  3263.0  18006.0  13.0  28.0  79.0     7.0      1.0    0.0      0.0
# 17647  3263.0  18007.0  13.0  28.0  79.0     7.0      1.0    0.0      0.0
# 17648  3263.0  18008.0  13.0  28.0  79.0     7.0      1.0    0.0      0.0
# 17649  3263.0  18009.0  13.0  28.0  79.0     7.0      1.0    0.0      0.0
#
#        ENTREV  ...  VOTOSIMG  P9BR  P13R  P14R  P15R  P17AR  RECUERDO  \
# ...
